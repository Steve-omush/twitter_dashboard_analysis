# %%
import pandas as pd

# List of file names
file_names = ["C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/worldcup/worldcup.xlsx",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/ukraine/ukraine.csv",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/Bitcoin/bit.csv",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/covid/covid.xlsx",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/worldcup/worldcup-1.xlsx",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/ukraine/ukraine-1.csv",
              "C:/Users/MACTECH/Downloads/Compressed/dataset/kaggle/covid/covid-1.xlsx",
             ]

# Initialize an empty list to store dataframes
dfs = []

# Iterate over each file
for file_name in file_names:
    # Read the CSV or Excel file into a DataFrame
    if file_name.endswith('.csv'):
        df = pd.read_csv(file_name)
    elif file_name.endswith('.xlsx'):
        df = pd.read_excel(file_name, engine='openpyxl')
    else:
        print(f"Unsupported file format: {file_name}")
        continue
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames in the list along rows
combined_df = pd.concat(dfs, ignore_index=True)
# Out:
# C:\Users\MACTECH\AppData\Local\Temp\ipykernel_10728\3862912482.py:20: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name)

# %%
combined_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1603309229871452160"  https://twitter.com/imrmkhan1/status/160330922...
# 1  "1603309229980487681"  https://twitter.com/Shahxaze1/status/160330922...
# 2  "1603309226469642240"  https://twitter.com/SorareAlexandre/status/160...
# 3  "1603309226604236800"  https://twitter.com/Woozie178/status/160330922...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  15 Dec 2022 08:41:23  "Field par Messi aur Mbappe… studio mein @Wayn...
# 1  15 Dec 2022 08:41:23  "𝐈𝐭. 𝐂𝐚𝐧𝐧𝐨𝐭. 𝐆𝐞𝐭. 𝐁𝐢𝐠𝐠𝐞𝐫. 𝐓𝐡𝐚𝐧. 𝐓𝐡𝐢𝐬. 🔥\n\nGet...
# 2  15 Dec 2022 08:41:22  "🎁 CONCOURS SORARE 🎁\n\nJOUEUR À GAGNER : SEKO...
# 3  15 Dec 2022 08:41:22  "It’ll be a tough night for Europe today.\n\n#...
#
#   Tweet Type                 Client  Retweets Received  Likes Received  \
# 0    ReTweet  "Twitter for Android"                  0               0
# ...

# %%
combined_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1603309229871452160"  https://twitter.com/imrmkhan1/status/160330922...
# 1  "1603309229980487681"  https://twitter.com/Shahxaze1/status/160330922...
# 2  "1603309226469642240"  https://twitter.com/SorareAlexandre/status/160...
# 3  "1603309226604236800"  https://twitter.com/Woozie178/status/160330922...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  15 Dec 2022 08:41:23  "Field par Messi aur Mbappe… studio mein @Wayn...
# 1  15 Dec 2022 08:41:23  "𝐈𝐭. 𝐂𝐚𝐧𝐧𝐨𝐭. 𝐆𝐞𝐭. 𝐁𝐢𝐠𝐠𝐞𝐫. 𝐓𝐡𝐚𝐧. 𝐓𝐡𝐢𝐬. 🔥\n\nGet...
# 2  15 Dec 2022 08:41:22  "🎁 CONCOURS SORARE 🎁\n\nJOUEUR À GAGNER : SEKO...
# 3  15 Dec 2022 08:41:22  "It’ll be a tough night for Europe today.\n\n#...
#
#   Tweet Type                 Client  Retweets Received  Likes Received  \
# 0    ReTweet  "Twitter for Android"                  0               0
# ...

# %%
import pandas as pd

# Assuming you already have the dataframe combined_df
# To find the number of rows and columns
num_rows, num_columns = combined_df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 296531
# Number of columns: 19

# %%
import pandas as pd

# Assuming your combined dataframe is called combined_df
sample_size = 5500
sampled_df = combined_df.sample(n=sample_size, random_state=42)

# If you want to reset the index of the sampled dataframe
sampled_df.reset_index(drop=True, inplace=True)

# %%
import pandas as pd

# Assuming you already have the dataframe combined_df
# To find the number of rows and columns
num_rows, num_columns = sampled_df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 5500
# Number of columns: 19

# %%
null_cols = sampled_df.columns[df.isnull().any()]
null_cols
# Out:
# Index(['Tweet Language'], dtype='object')

# %%
# Check for missing values in the combined DataFrame
missing_values = combined_df.isnull().sum()

# Print the count of missing values for each column
print("Missing Values:")
missing_values
# Out:
# Missing Values:
# Tweet Id                         0
# Tweet URL                        0
# Tweet Posted Time                0
# Tweet Content                    0
# Tweet Type                       0
# Client                           0
# Retweets Received                0
# Likes Received                   0
# Tweet Location                   0
# Tweet Language                5430
# User  Id                         0
# Name                             0
# Username                         0
# User Bio                         0
# Verified or Non-Verified         2
# Profile URL                      2
# User Followers                   2
# User Following                   3
# User Account Creation Date       3
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Assuming you already have the dataframe combined_df
# To randomly generate numerical values between 300 to 1200 for the "Retweet Received" and "Likes Received" columns
sampled_df["Retweets Received"] = np.random.randint(100, 2500, size=len(sampled_df))
sampled_df["Likes Received"] = np.random.randint(500, 7000, size=len(sampled_df))

# %%
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 1  "1547963214574391297"  https://twitter.com/alexmeshkin/status/1547963...
# 2  "1603279607695671296"  https://twitter.com/poptarts5001/status/160327...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 1  15 Jul 2022 15:16:04          "“Pandemic of Greater than 50 years old”"
# 2  15 Dec 2022 06:43:40         "The problem is the religion not the game"
# 3  15 Dec 2022 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
#
#   Tweet Type                Client  Retweets Received  Likes Received  \
# 0      Tweet     "Twitter Web App"               1801            2746
# ...

# %%
#getting the Sentiments column from calculating sentiments of Tweet Content column
from textblob import TextBlob

# Assuming 'sampled_df' is your dataframe and 'Tweet Column' is the column containing the tweet text
sampled_df['Sentiments'] = sampled_df['Tweet Content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 1  "1547963214574391297"  https://twitter.com/alexmeshkin/status/1547963...
# 2  "1603279607695671296"  https://twitter.com/poptarts5001/status/160327...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 1  15 Jul 2022 15:16:04          "“Pandemic of Greater than 50 years old”"
# 2  15 Dec 2022 06:43:40         "The problem is the religion not the game"
#
#   Tweet Type                Client  Retweets Received  Likes Received  \
# 0      Tweet     "Twitter Web App"               1801            2746
# 1      Tweet  "Twitter for iPhone"                369            2764
# 2    ReTweet     "Twitter Web App"               1516            5333
#
# ...

# %%
import pandas as pd 

#get number of rows and columns
num_rows, num_cols = sampled_df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 5500
# Number of columns: 20

# %%
#extract hashtags from the Tweet Content column by checking the "#" symbol
import pandas as pd
import re


# Define a function to extract hashtags from a given text
def extract_hashtags(text):
    hashtags = re.findall(r"#(\w+)", text)
    return ",".join(hashtags)

# Apply the hashtag extraction function to the "Tweet Content" column and save the result to a new column called "Hashtags"
sampled_df["Hashtags"] = sampled_df["Tweet Content"].apply(extract_hashtags)

# Drop rows where the "Hashtags" column is missing
sampled_df = sampled_df.dropna(subset=["Hashtags"])

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 1  "1547963214574391297"  https://twitter.com/alexmeshkin/status/1547963...
# 2  "1603279607695671296"  https://twitter.com/poptarts5001/status/160327...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 1  15 Jul 2022 15:16:04          "“Pandemic of Greater than 50 years old”"
# 2  15 Dec 2022 06:43:40         "The problem is the religion not the game"
#
#   Tweet Type                Client  Retweets Received  Likes Received  \
# 0      Tweet     "Twitter Web App"               1801            2746
# 1      Tweet  "Twitter for iPhone"                369            2764
# 2    ReTweet     "Twitter Web App"               1516            5333
#
# ...

# %%
sampled_df = sampled_df.dropna(subset=['Hashtags'])

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 1  "1547963214574391297"  https://twitter.com/alexmeshkin/status/1547963...
# 2  "1603279607695671296"  https://twitter.com/poptarts5001/status/160327...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 1  15 Jul 2022 15:16:04          "“Pandemic of Greater than 50 years old”"
# 2  15 Dec 2022 06:43:40         "The problem is the religion not the game"
#
#   Tweet Type                Client  Retweets Received  Likes Received  \
# 0      Tweet     "Twitter Web App"               1801            2746
# 1      Tweet  "Twitter for iPhone"                369            2764
# 2    ReTweet     "Twitter Web App"               1516            5333
#
# ...

# %%
import pandas as pd
import re
import numpy as np


# Define a function to extract hashtags from a given text
def extract_hashtags(text):
    hashtags = re.findall(r"#(\w+)", text)
    return hashtags if hashtags else None

# Apply the hashtag extraction function to the "Tweet Content" column
sampled_df["Hashtags"] = sampled_df["Tweet Content"].apply(extract_hashtags)

# Replace 0 values in the "Hashtags" column with NaN
sampled_df["Hashtags"] = sampled_df["Hashtags"].replace(0, np.nan)

# Drop rows where the "Hashtags" column is missing
sampled_df = sampled_df.dropna(subset=["Hashtags"])

# Flatten the list of hashtags and count their frequency
hashtags = sampled_df["Hashtags"].explode().value_counts()

# Print the top 10 most popular hashtags
print(hashtags.head(10))
# Out:
# Hashtags
# FIFAWorldCup        1467
# COVID19             1161
# UkraineWar           633
# Bitcoin              555
# Ukraine              350
# Qatar2022            244
# bitcoin              218
# Covid19              203
# UkraineRussiaWar     202
# covid19              165
# Name: count, dtype: int64

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 3  15 Dec 2022 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5  16 Sep 2022 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# 3    ReTweet         "Twitter Web App"                106            1110
# 5      Tweet  "Greatly Social Twitter"               1628            6514
#
# ...

# %%
# Check for missing values in the combined DataFrame
missing_values = combined_df.isnull().sum()

# Print the count of missing values for each column
print("Missing Values:")
missing_values
# Out:
# Missing Values:
# Tweet Id                         0
# Tweet URL                        0
# Tweet Posted Time                0
# Tweet Content                    0
# Tweet Type                       0
# Client                           0
# Retweets Received                0
# Likes Received                   0
# Tweet Location                   0
# Tweet Language                5430
# User  Id                         0
# Name                             0
# Username                         0
# User Bio                         0
# Verified or Non-Verified         2
# Profile URL                      2
# User Followers                   2
# User Following                   3
# User Account Creation Date       3
# dtype: int64

# %%
unique_languages = sampled_df['Tweet Language'].unique()
unique_languages
# Out:
# array(['English', 'ht', 'German', 'Japanese', nan, 'Italian', 'French',
#        'Hindi', 'Dutch', 'Spanish', 'qht', 'in', 'Urdu', 'Tagalog',
#        'Arabic', 'qme', 'Tamil', 'Russian', 'Portuguese', 'Polish',
#        'Ukrainian', 'Turkish', 'Greek', 'Czech', 'Thai', 'Marathi',
#        'Estonian', 'Welsh', 'Chinese', 'Finnish', 'or', 'Romanian',
#        'Catalan', 'Farsi', 'no', 'Gujarati', 'Korean', 'si', 'Swedish',
#        'Danish', 'Basque', 'Telugu', 'ml', 'Slovenian', 'Kannada',
#        'Vietnamese', 'bn'], dtype=object)

# %%
#add the random languages to Tweet Language column
languages = ['Arabic', 'Hindi', 'Turkish', 'Tamil', 'English', 'Japanese', 'in',
             'French','Spanish', 'Portuguese', 'qme', 'Ukrainian',
             'Basque', 'German', 'Russian', 'Estonian', 'Italian', 'no',
             'Farsi', 'Catalan', 'Thai', 'Welsh', 'Urdu', 'Korean', 'Telugu',
             'qht', 'my', 'ht', 'Czech', 'Dutch', 'or', 'Romanian', 'Danish',
             'Tagalog', 'Chinese', 'Polish', 'Greek', 'Gujarati', 'Kannada',
             'bn', 'Vietnamese', 'Slovenian']
# Replace missing values in the 'Tweet Language' column with a random language value
sampled_df['Tweet Language'] = sampled_df['Tweet Language'].fillna(pd.Series(np.random.choice(languages, size=len(sampled_df.index))))

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  18 Aug 2022 06:20:51  "Russian passport holders entering Romania now...
# 3  15 Dec 2022 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5  16 Sep 2022 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# 3    ReTweet         "Twitter Web App"                106            1110
# 5      Tweet  "Greatly Social Twitter"               1628            6514
#
# ...

# %%
# Check for missing values in the combined DataFrame
missing_values = sampled_df.isnull().sum()

# Print the count of missing values for each column
print("Missing Values:")
missing_values
# Out:
# Missing Values:
# Tweet Id                      0
# Tweet URL                     0
# Tweet Posted Time             0
# Tweet Content                 0
# Tweet Type                    0
# Client                        0
# Retweets Received             0
# Likes Received                0
# Tweet Location                0
# Tweet Language                9
# User  Id                      0
# Name                          0
# Username                      0
# User Bio                      0
# Verified or Non-Verified      0
# Profile URL                   0
# User Followers                0
# User Following                0
# User Account Creation Date    0
# Sentiments                    0
# Hashtags                      0
# dtype: int64

# %%
# save this dataframe so far to a new csv file
import os

# Define the file path
file_path = r"C:\Users\MACTECH\OneDrive\Desktop\4.2\REAL PROJECT\csv\tweet-language.csv"

# Save the dataframe to a new CSV file
sampled_df.to_csv(file_path, index=False)

# %%
unique_locations = sampled_df['Tweet Location'].unique()
unique_locations
# Out:
# array(['""', '"The Grafton 日本"', '"Hyderabad, India India"',
#        '"Argentina Argentina"', '"Des Moines, IA United States"',
#        '"Abuja, Nigeria Nigeria"',
#        '"Central Region, Singapore Singapore"',
#        '"Al Janoub Stadium دولة قطر"', '"Quevedo, Ecuador Ecuador"',
#        '"Portland, OR United States"', '"Davie, FL United States"',
#        '"Ghaziabad, India India"', '"Ukraine Ukraine"',
#        '"González Catán, Argentina Argentina"',
#        '"Tamil Nadu, India India"',
#        '"Adelaide, South Australia Australia"', '"Lille, France France"',
#        '"Oakland, CA United States"', '"Florianópolis, Brasil Brasil"',
#        '"Randburg, South Africa South Africa"',
#        '"Dhaka, Bangladesh Bangladesh"'], dtype=object)

# %%
locations = ['United States of America', 'United Kingdom', 'France', 'Canada','Mexico','United Arab Emirates', 'Germany', 'India', 'Nigeria', 'Kenya', 'Argentina', 'Pakistan','Russia', 'Ukraine', 'Japan', 'China', 'South Korea', 'Australia', 'New Zealand', 'South Africa', 'Egypt', 'Algeria', 'Gabon', 'Namibia', 'Brazil', 'Palestine', 'Israel', 'Saudi Arabia', 'Spain', 'Portugal', 'Morocco', 'Fiji', 'Indonesia', 'Cameroon', 'Italy', 'Greece', 'Norway', 'Finland', 'Brazil', 'Peru', 'Colombia', 'Jamaica', 'Cuba', 'Fiji', 'Antarctica', 'Zimbabwe', 'Chad', 'Togo', 'Tanzania','Belgium', 'Croatia', 'France', 'Switzerland', 'Netherlands', 'Czechia', 'Poland', 'Liberia']

# %%
import pandas as pd
import random

sampled_df['Tweet Location'] = random.choices(locations, k=len(sampled_df))

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# 3    ReTweet         "Twitter Web App"                106            1110
# 5      Tweet  "Greatly Social Twitter"               1628            6514
#
# ...

# %%
# Get unique locations with their counts
unique_locations = sampled_df['Tweet Location'].value_counts()

# Display the unique locations with their counts
unique_locations
# Out:
# Tweet Location
# Brazil                      184
# France                      182
# Fiji                        157
# Japan                        98
# Germany                      95
# United States of America     94
# Peru                         94
# Jamaica                      93
# Norway                       92
# Chad                         92
# Indonesia                    89
# Australia                    89
# Saudi Arabia                 88
# Zimbabwe                     87
# Portugal                     87
# Spain                        86
# Antarctica                   86
# Colombia                     86
# Poland                       86
# Greece                       85
# Cuba                         85
# Algeria                      84
# Mexico                       84
# United Kingdom               84
# China                        83
# Liberia                      83
# Croatia                      83
# Cameroon                     82
# ...

# %%
# Assuming 'Tweet Posted Time' is in a format like 'YYYY-MM-DD HH:MM:SS'
sampled_df['Tweet Posted Time'] = pd.to_datetime(sampled_df['Tweet Posted Time'])
sampled_df['YearMonth of Tweet'] = sampled_df['Tweet Posted Time'].dt.to_period('M')

# Display the DataFrame with the new 'YearMonth' column
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# ...

# %%
# Extract the time in hours, minutes, and seconds
sampled_df['Tweet Time'] = sampled_df['Tweet Posted Time'].dt.strftime('%H:%M:%S')

# %%
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# ...

# %%
# Assuming 'Tweet Posted Time' is in a format like 'YYYY-MM-DD HH:MM:SS'
sampled_df['User Account Creation Date'] = pd.to_datetime(sampled_df['User Account Creation Date'])
sampled_df['YearMonth of User'] = sampled_df['User Account Creation Date'].dt.to_period('M')

# Display the DataFrame with the new 'YearMonth' column
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# ...

# %%
# Extract the time in hours, minutes, and seconds
sampled_df['User Time'] = sampled_df['User Account Creation Date'].dt.strftime('%H:%M:%S')
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# ...

# %%
print("Unique User Account Creation Date values:")
print(sampled_df['User Account Creation Date'].unique())

print("\nUnique Tweet Posted Time values:")
print(sampled_df['Tweet Posted Time'].unique())
# Out:
# Unique User Account Creation Date values:
# <DatetimeArray>
# ['2014-09-15 15:26:59', '2022-05-16 22:55:45', '2022-01-31 21:11:11',
#  '2013-10-16 22:39:53', '2022-05-16 17:23:48', '2015-01-10 20:23:49',
#  '2016-01-06 06:40:11', '2022-06-22 22:50:51', '2015-04-14 19:57:17',
#  '2021-05-31 10:19:28',
#  ...
#  '2022-06-22 20:57:26', '2010-09-05 13:26:02', '2014-09-18 14:03:24',
#  '2020-06-29 12:14:10', '2010-06-28 00:34:17', '2010-08-25 09:51:45',
#  '2021-01-06 02:50:39', '2014-02-27 19:16:52', '2021-02-13 19:32:57',
#  '2022-07-24 12:51:33']
# Length: 4296, dtype: datetime64[ns]
#
# Unique Tweet Posted Time values:
# <DatetimeArray>
# ['2022-08-18 06:20:51', '2022-12-15 00:08:37', '2022-09-16 18:04:03',
#  '2022-07-15 14:41:52', '2022-12-15 05:40:10', '2022-07-15 16:45:41',
#  '2022-12-15 02:48:04', '2022-09-16 19:45:53', '2022-07-15 20:50:29',
#  '2022-12-15 03:52:41',
#  ...
#  '2022-07-15 12:39:51', '2022-12-15 08:24:02', '2022-07-16 07:44:26',
# ...

# %%
sampled_df
# Out:
#                    Tweet Id  \
# 0     "1560149710895202304"
# 3     "1603180191097856000"
# 5     "1570835924472442880"
# 6     "1547954607502299136"
# 7     "1603263626827145216"
# ...                     ...
# 5492  "1562595647642947591"
# 5493  "1570836967579062272"
# 5494  "1548410115425939457"
# 5496  "1603270309829922818"
# 5498  "1603252532532645890"
#
#                                               Tweet URL   Tweet Posted Time  \
# 0     https://twitter.com/crypt0nerd/status/15601497... 2022-08-18 06:20:51
# 3     https://twitter.com/0x_Tommy_Cash/status/16031... 2022-12-15 00:08:37
# 5     https://twitter.com/BeautifulZombi2/status/157... 2022-09-16 18:04:03
# 6     https://twitter.com/FrancCrist/status/15479546... 2022-07-15 14:41:52
# 7     https://twitter.com/Justevansss/status/1603263... 2022-12-15 05:40:10
# ...                                                 ...                 ...
# 5492  https://twitter.com/adenter/status/15625956476... 2022-08-25 00:20:08
# ...

# %%
top_hashtags = sampled_df['Hashtags'].value_counts().head(10)

# %%
top_hashtags
# Out:
# Hashtags
# [FIFAWorldCup]                                                  394
# [COVID19]                                                       346
# [Bitcoin]                                                       189
# [dugina, UkraineWar, FSB, fake]                                 109
# [Pathaan, FIFAWorldCup]                                          70
# [FIFA, GOAT𓃵, FIFA22, FIFA22, LeoMessi, Messi, FIFAWorldCup]     66
# [bitcoin]                                                        60
# [FIFAWorldCup, Qatar2022]                                        59
# [COVID19, COVID19France, coronavirus]                            43
# [ثريد]                                                           43
# Name: count, dtype: int64

# %%
unique_clients = sampled_df['Client'].value_counts().head(10)
unique_clients
# Out:
# Client
# "Twitter for Android"    2190
# "Twitter Web App"        1084
# "Twitter for iPhone"      979
# "Twitter for iPad"         88
# "TweetDeck"                52
# "Hephaistos bot"           23
# "Hootsuite Inc."           13
# "PHDS bot mark 2"           9
# "IFTTT"                     9
# "dlvr.it"                   8
# Name: count, dtype: int64

# %%
verified_count = sampled_df[sampled_df['Verified or Non-Verified'] == 'Verified'].shape[0]
print("Verified User")
verified_count
# Out:
# Verified User
# 95

# %%
non_verified_count = sampled_df[sampled_df['Verified or Non-Verified'] == 'Non-Verified'].shape[0]
print("Non Verified User")
non_verified_count
# Out:
# Non Verified User
# 4583

# %%
unique_languages = sampled_df['Tweet Language'].value_counts().head(10)
unique_languages
# Out:
# Tweet Language
# English     2714
# Spanish      420
# French       385
# Turkish      153
# Hindi        122
# Japanese     107
# Arabic       100
# in            92
# qht           66
# qme           62
# Name: count, dtype: int64

# %%
# Count the number of tweets and retweets
tweet_count = sampled_df[sampled_df['Tweet Type'] == 'Tweet'].shape[0]
retweet_count = sampled_df[sampled_df['Tweet Type'] == 'ReTweet'].shape[0]

# Display the results
print("Number of Tweets:", tweet_count)
print("Number of Retweets:", retweet_count)
# Out:
# Number of Tweets: 988
# Number of Retweets: 3495

# %%
# Save the preprocessed DataFrame to a CSV file
sampled_df.to_csv(r'C:\Users\MACTECH\OneDrive\Desktop\4.2\REAL PROJECT\csv\preprocessed.csv', index=False)

# Confirm that the file has been saved
print("DataFrame saved to preprocessed.csv")
# Out:
# DataFrame saved to preprocessed.csv

# %%
top_hashtags
# Out:
# Hashtags
# [FIFAWorldCup]                                                  394
# [COVID19]                                                       346
# [Bitcoin]                                                       189
# [dugina, UkraineWar, FSB, fake]                                 109
# [Pathaan, FIFAWorldCup]                                          70
# [FIFA, GOAT𓃵, FIFA22, FIFA22, LeoMessi, Messi, FIFAWorldCup]     66
# [bitcoin]                                                        60
# [FIFAWorldCup, Qatar2022]                                        59
# [COVID19, COVID19France, coronavirus]                            43
# [ثريد]                                                           43
# Name: count, dtype: int64

# %%
top_hashtags
# Out:
# Hashtags
# [FIFAWorldCup]                                                  394
# [COVID19]                                                       346
# [Bitcoin]                                                       189
# [dugina, UkraineWar, FSB, fake]                                 109
# [Pathaan, FIFAWorldCup]                                          70
# [FIFA, GOAT𓃵, FIFA22, FIFA22, LeoMessi, Messi, FIFAWorldCup]     66
# [bitcoin]                                                        60
# [FIFAWorldCup, Qatar2022]                                        59
# [COVID19, COVID19France, coronavirus]                            43
# [ثريد]                                                           43
# Name: count, dtype: int64

# %%
sampled_df.head(4)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# ...

# %%
hashtags_column = sampled_df['Hashtags']

# Flatten the list of hashtags
flattened_hashtags = [tag for sublist in hashtags_column for tag in sublist]

# Create a pandas Series from the flattened list of hashtags
hashtag_counts = pd.Series(flattened_hashtags)

# Count the occurrences of each hashtag and select the top 10
top_10_hashtags = hashtag_counts.value_counts().head(10)

# Display the top 10 hashtags
print(top_10_hashtags)
# Out:
# FIFAWorldCup        1467
# COVID19             1161
# UkraineWar           633
# Bitcoin              555
# Ukraine              350
# Qatar2022            244
# bitcoin              218
# Covid19              203
# UkraineRussiaWar     202
# covid19              165
# Name: count, dtype: int64

# %%
sampled_df.head(3)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
#
#   Tweet Type                    Client  Retweets Received  Likes Received  \
# 0      Tweet         "Twitter Web App"               1801            2746
# 3    ReTweet         "Twitter Web App"                106            1110
# 5      Tweet  "Greatly Social Twitter"               1628            6514
#
# ...

# %%
sampled_df['Flattened_Hashtags'] = sampled_df['Hashtags'].apply(lambda x: ', '.join(x))

# %%
print(sampled_df[['Hashtags', 'Flattened_Hashtags']].head())
# Out:
#                                             Hashtags  \
# 0     [UkraineWar, UkraineWillWin, RussianWarCrimes]
# 3                         [FAFC, FIFA, FIFAWorldCup]
# 5  [Tag, Follow, Twitter, Instagram, Discord, NFT...
# 6                                    [mRNA, COVID19]
# 7                                     [FIFAWorldCup]
#
#                                   Flattened_Hashtags
# 0       UkraineWar, UkraineWillWin, RussianWarCrimes
# 3                           FAFC, FIFA, FIFAWorldCup
# 5  Tag, Follow, Twitter, Instagram, Discord, NFTs...
# 6                                      mRNA, COVID19
# 7                                       FIFAWorldCup

# %%
sampled_df.head(5)
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1560149710895202304"  https://twitter.com/crypt0nerd/status/15601497...
# 3  "1603180191097856000"  https://twitter.com/0x_Tommy_Cash/status/16031...
# 5  "1570835924472442880"  https://twitter.com/BeautifulZombi2/status/157...
# 6  "1547954607502299136"  https://twitter.com/FrancCrist/status/15479546...
# 7  "1603263626827145216"  https://twitter.com/Justevansss/status/1603263...
#
#     Tweet Posted Time                                      Tweet Content  \
# 0 2022-08-18 06:20:51  "Russian passport holders entering Romania now...
# 3 2022-12-15 00:08:37  "Missed BAYC? Don’t miss #FAFC WL Giveaway! #F...
# 5 2022-09-16 18:04:03  "#Tag 3 Friends\n#Follow us on #Twitter , #Ins...
# 6 2022-07-15 14:41:52  "Health Canada (@GovCanHealth) has approved th...
# 7 2022-12-15 05:40:10  "Dembele RIP Twitch Mbappe Amrabat Pogba Tchou...
#
# ...

# %%
hashtag_counts = sampled_df['Flattened_Hashtags'].str.split(',').explode().value_counts()

# %%
top_10_hashtags = hashtag_counts.head(10)

# Display the top 10 hashtags
print(top_10_hashtags)
# Out:
# Flattened_Hashtags
#  FIFAWorldCup        743
# FIFAWorldCup         724
# COVID19              708
#  UkraineWar          533
#  COVID19             453
# Bitcoin              298
#  Bitcoin             257
#  Ukraine             250
#  Qatar2022           204
#  UkraineRussiaWar    158
# Name: count, dtype: int64

# %%
# Split hashtags by commas and create a list of all hashtags
all_hashtags = [tag.strip() for row in sampled_df['Flattened_Hashtags'] for tag in row.split(',')]

# Create a pandas Series from the list of hashtags
hashtag_counts = pd.Series(all_hashtags)

# Count the occurrences of each hashtag and select the top 10
top_10_hashtags = hashtag_counts.value_counts().head(10)

# Display the top 10 hashtags
print(top_10_hashtags)
# Out:
# FIFAWorldCup        1467
# COVID19             1161
# UkraineWar           633
# Bitcoin              555
# Ukraine              350
# Qatar2022            244
# bitcoin              218
# Covid19              203
# UkraineRussiaWar     202
# covid19              165
# Name: count, dtype: int64

# %%
# Save the preprocessed DataFrame to a CSV file
sampled_df.to_csv(r'C:\Users\MACTECH\OneDrive\Desktop\4.2\REAL PROJECT\csv\preprocessed.csv', index=False)

# Confirm that the file has been saved
print("DataFrame saved to preprocessed.csv")
# Out:
# DataFrame saved to preprocessed.csv

# %%
print(sampled_df['Flattened_Hashtags'].dtype)
# Out:
# object

# %%
sampled_df['Flattened_Hashtags'].dtype
# Out:
# dtype('O')

# %%
username = "IndianExpress"
user_followers = sampled_df[sampled_df["Username"] == username]["User Followers"].values[0]

print(f"User Followers for {username}: {user_followers}")
# Out:
# User Followers for IndianExpress: 4246058

# %%
tweet_location = sampled_df.loc[sampled_df['Username'] == 'franceinfo', 'Tweet Location'].iloc[0]
print(tweet_location)
# Out:
# Portugal

# %%
tweet_location = sampled_df.loc[sampled_df['Username'] == 'teleSURtv', 'Tweet Location'].iloc[0]
print(tweet_location)
# Out:
# Finland
